# %%
#importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")
# set to display all the columns in dataset
pd.set_option("display.max_columns",None)
#to run sql quries on data frame
import pandasql as psql

# %%
smoke=pd.read_csv(r"C:\Users\SATISH VARMA\Downloads\smoking.csv",header=0)
smoke_bk=smoke.copy()
smoke.head()
# Out:
#    ID gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0   0      F   40         155          60       81.3             1.2
# 1   1      F   40         160          60       81.0             0.8
# 2   2      M   55         170          60       80.0             0.8
# 3   3      M   40         165          70       88.0             1.5
# 4   4      F   40         155          60       86.0             1.0
#
#    eyesight(right)  hearing(left)  hearing(right)  systolic  relaxation  \
# 0              1.0            1.0             1.0     114.0        73.0
# 1              0.6            1.0             1.0     119.0        70.0
# 2              0.8            1.0             1.0     138.0        86.0
# 3              1.5            1.0             1.0     100.0        60.0
# 4              1.0            1.0             1.0     120.0        74.0
#
#    fasting blood sugar  Cholesterol  triglyceride   HDL    LDL  hemoglobin  \
# 0                 94.0        215.0          82.0  73.0  126.0        12.9
# 1                130.0        192.0         115.0  42.0  127.0        12.7
# 2                 89.0        242.0         182.0  55.0  151.0        15.8
# 3                 96.0        322.0         254.0  45.0  226.0        14.7
# 4                 80.0        184.0          74.0  62.0  107.0        12.5
#
#    Urine protein  serum creatinine   AST   ALT   Gtp oral  dental caries  \
# 0            1.0               0.7  18.0  19.0  27.0    Y              0
# 1            1.0               0.6  22.0  19.0  18.0    Y              0
# 2            1.0               1.0  21.0  16.0  22.0    Y              0
# 3            1.0               1.0  19.0  26.0  18.0    Y              0
# 4            1.0               0.6  16.0  14.0  22.0    Y              0
#
#   tartar  smoking
# 0      Y        0
# 1      Y        0
# 2      N        1
# 3      Y        0
# 4      N        0

# %%
smoke.columns
# Out:
# Index(['ID', 'gender', 'age', 'height(cm)', 'weight(kg)', 'waist(cm)',
#        'eyesight(left)', 'eyesight(right)', 'hearing(left)', 'hearing(right)',
#        'systolic', 'relaxation', 'fasting blood sugar', 'Cholesterol',
#        'triglyceride', 'HDL', 'LDL', 'hemoglobin', 'Urine protein',
#        'serum creatinine', 'AST', 'ALT', 'Gtp', 'oral', 'dental caries',
#        'tartar', 'smoking'],
#       dtype='object')

# %%
smoke.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55692 entries, 0 to 55691
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   55692 non-null  int64
#  1   gender               55692 non-null  object
#  2   age                  55692 non-null  int64
#  3   height(cm)           55692 non-null  int64
#  4   weight(kg)           55692 non-null  int64
#  5   waist(cm)            55692 non-null  float64
#  6   eyesight(left)       55692 non-null  float64
#  7   eyesight(right)      55692 non-null  float64
#  8   hearing(left)        55692 non-null  float64
#  9   hearing(right)       55692 non-null  float64
#  10  systolic             55692 non-null  float64
#  11  relaxation           55692 non-null  float64
#  12  fasting blood sugar  55692 non-null  float64
#  13  Cholesterol          55692 non-null  float64
#  14  triglyceride         55692 non-null  float64
#  15  HDL                  55692 non-null  float64
#  16  LDL                  55692 non-null  float64
#  17  hemoglobin           55692 non-null  float64
#  18  Urine protein        55692 non-null  float64
#  19  serum creatinine     55692 non-null  float64
#  20  AST                  55692 non-null  float64
#  21  ALT                  55692 non-null  float64
#  22  Gtp                  55692 non-null  float64
#  23  oral                 55692 non-null  object
#  24  dental caries        55692 non-null  int64
#  25  tartar               55692 non-null  object
#  26  smoking              55692 non-null  int64
# dtypes: float64(18), int64(6), object(3)
# memory usage: 11.5+ MB

# %%
del smoke_bk["ID"]

# %%
smoke.dtypes
# Out:
# ID                       int64
# gender                  object
# age                      int64
# height(cm)               int64
# weight(kg)               int64
# waist(cm)              float64
# eyesight(left)         float64
# eyesight(right)        float64
# hearing(left)          float64
# hearing(right)         float64
# systolic               float64
# relaxation             float64
# fasting blood sugar    float64
# Cholesterol            float64
# triglyceride           float64
# HDL                    float64
# LDL                    float64
# hemoglobin             float64
# Urine protein          float64
# serum creatinine       float64
# AST                    float64
# ALT                    float64
# Gtp                    float64
# oral                    object
# dental caries            int64
# tartar                  object
# smoking                  int64
# dtype: object

# %%
smoke_bk["gender"].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
smoke_bk["gender"]=smoke_bk["gender"].map({"F":0,"M":1})

# %%
from sklearn.preprocessing import LabelEncoder
obj=LabelEncoder()
col=["oral","tartar"]
for i in col:
  smoke_bk[i]=obj.fit_transform(smoke_bk[i])

# %%
smoke_bk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55692 entries, 0 to 55691
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   gender               55692 non-null  int64
#  1   age                  55692 non-null  int64
#  2   height(cm)           55692 non-null  int64
#  3   weight(kg)           55692 non-null  int64
#  4   waist(cm)            55692 non-null  float64
#  5   eyesight(left)       55692 non-null  float64
#  6   eyesight(right)      55692 non-null  float64
#  7   hearing(left)        55692 non-null  float64
#  8   hearing(right)       55692 non-null  float64
#  9   systolic             55692 non-null  float64
#  10  relaxation           55692 non-null  float64
#  11  fasting blood sugar  55692 non-null  float64
#  12  Cholesterol          55692 non-null  float64
#  13  triglyceride         55692 non-null  float64
#  14  HDL                  55692 non-null  float64
#  15  LDL                  55692 non-null  float64
#  16  hemoglobin           55692 non-null  float64
#  17  Urine protein        55692 non-null  float64
#  18  serum creatinine     55692 non-null  float64
#  19  AST                  55692 non-null  float64
#  20  ALT                  55692 non-null  float64
#  21  Gtp                  55692 non-null  float64
#  22  oral                 55692 non-null  int32
#  23  dental caries        55692 non-null  int64
#  24  tartar               55692 non-null  int32
#  25  smoking              55692 non-null  int64
# dtypes: float64(18), int32(2), int64(6)
# memory usage: 10.6 MB

# %%
smoke_bk['smoking'].value_counts()
# Out:
# 0    35237
# 1    20455
# Name: smoking, dtype: int64

# %%
# Assuming 'smoke' is the name of the target variable
# Count occurrences of each class (0 and 1)
smoke_count=smoke.smoking.value_counts()
# Print the counts of each class
print("Class 0: ",smoke_count[0])
print("Class 1: ",smoke_count[1])
# Calculate the proportion of class 0 to class 1
print("Proportion: ",round(smoke_count[0]/smoke_count[1],2),':1')
# Calculate the total number of records in the dataset
print("Total Bank records: ",len(smoke))
# Out:
# Class 0:  35237
# Class 1:  20455
# Proportion:  1.72 :1
# Total Bank records:  55692

# %% [markdown]
# #  Define independent and Target(dependent) variables

# %%
#Identify the independent and Target(dependent) variables
inde=[]
for i in smoke_bk.columns:
  if i!="smoking":
    inde.append(i)
x=smoke_bk[inde]
y=smoke_bk["smoking"]

# %%
#Splitting the dataset into train and test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=40)
#Display the shape of train and test data
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((38984, 25), (16708, 25), (38984,), (16708,))

# %%
x_train.head()
# Out:
#        gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 54953       1   60         175          75       96.0             0.8
# 48442       1   25         175          70       78.0             1.2
# 30301       0   50         160          65       84.0             1.0
# 7762        0   40         155          60       76.0             1.2
# 45373       1   45         170          70       81.0             1.2
#
#        eyesight(right)  hearing(left)  hearing(right)  systolic  relaxation  \
# 54953              0.8            1.0             1.0     149.0        87.0
# 48442              1.2            1.0             1.0     110.0        60.0
# 30301              1.5            1.0             1.0     123.0        79.0
# 7762               1.0            1.0             1.0     107.0        62.0
# 45373              1.5            1.0             1.0     120.0        80.0
#
#        fasting blood sugar  Cholesterol  triglyceride   HDL    LDL  \
# 54953                104.0        139.0         131.0  36.0   77.0
# 48442                 93.0        197.0         101.0  63.0  114.0
# 30301                113.0        199.0         120.0  49.0  126.0
# 7762                  79.0        324.0          44.0  55.0  260.0
# 45373                 94.0        218.0         274.0  42.0  121.0
#
#        hemoglobin  Urine protein  serum creatinine   AST   ALT   Gtp  oral  \
# 54953        14.9            2.0               0.7  52.0  80.0  46.0     0
# 48442        16.0            1.0               1.2  20.0  22.0  36.0     0
# 30301        13.4            1.0               0.7  18.0  16.0  17.0     0
# 7762         12.4            1.0               1.0  22.0  18.0  15.0     0
# 45373        16.4            1.0               1.1  22.0  29.0  52.0     0
#
#        dental caries  tartar
# 54953              0       1
# 48442              0       0
# 30301              0       0
# 7762               0       1
# 45373              0       1

# %%
y_train[0:5]
# Out:
# 54953    1
# 48442    0
# 30301    0
# 7762     0
# 45373    1
# Name: smoking, dtype: int64

# %% [markdown]
# # Splitting The Features

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=40)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((38984, 25), (16708, 25), (38984,), (16708,))

# %% [markdown]
# # Scaling the features

# %%
from sklearn.preprocessing import MinMaxScaler
scal_ob=MinMaxScaler(feature_range=(0,1))
x_train=scal_ob.fit_transform(x_train)
x_train=pd.DataFrame(x_train)
x_test=scal_ob.fit_transform(x_test)
x_test=pd.DataFrame(x_test)

# %%
x_train.head()
# Out:
#     0         1         2     3         4         5         6    7    8   \
# 0  1.0  0.615385  0.727273  0.45  0.584416  0.071429  0.071429  0.0  0.0
# 1  1.0  0.076923  0.727273  0.40  0.350649  0.112245  0.112245  0.0  0.0
# 2  0.0  0.461538  0.454545  0.35  0.428571  0.091837  0.142857  0.0  0.0
# 3  0.0  0.307692  0.363636  0.30  0.324675  0.112245  0.091837  0.0  0.0
# 4  1.0  0.384615  0.636364  0.40  0.389610  0.112245  0.142857  0.0  0.0
#
#          9         10        11        12        13        14        15  \
# 0  0.461538  0.443396  0.131148  0.179625  0.268559  0.090141  0.042012
# 1  0.230769  0.188679  0.105386  0.335121  0.203057  0.166197  0.062465
# 2  0.307692  0.367925  0.152225  0.340483  0.244541  0.126761  0.069099
# 3  0.213018  0.207547  0.072600  0.675603  0.078603  0.143662  0.143173
# 4  0.289941  0.377358  0.107728  0.391421  0.580786  0.107042  0.066335
#
#         16   17        18        19        20        21   22   23   24
# 0  0.62500  0.2  0.052174  0.035249  0.027120  0.044132  0.0  0.0  1.0
# 1  0.69375  0.0  0.095652  0.010728  0.007209  0.034102  0.0  0.0  0.0
# 2  0.53125  0.0  0.052174  0.009195  0.005149  0.015045  0.0  0.0  0.0
# 3  0.46875  0.0  0.078261  0.012261  0.005836  0.013039  0.0  0.0  1.0
# 4  0.71875  0.0  0.086957  0.012261  0.009612  0.050150  0.0  0.0  1.0

# %% [markdown]
# # Data visualisation

# %%
d = np.array([36548,4640])
l=["no","yes"]

plt.pie(d,labels=l)
# Out:
# ([<matplotlib.patches.Wedge at 0x222494e7bb0>,
#   <matplotlib.patches.Wedge at 0x222494e6c50>],
#  [Text(-1.0318259710710267, 0.3812284950306482, 'no'),
#   Text(1.031825997840915, -0.3812284225757576, 'yes')])

# %%
# Example: Scatter plot for 'weight(kg)' vs. 'height(cm)'
plt.scatter(smoke['weight(kg)'], smoke['height(cm)'])
plt.xlabel('Weight (kg)')
plt.ylabel('Height (cm)')
plt.title('Weight vs. Height')
plt.show()

# %% [markdown]
# # KNN_algorithm

# %%
KNN_Results=pd.read_csv(r"C:\Users\SATISH VARMA\Downloads\KNN_Results.csv",header=0)
KNN_Results.head()
# Out:
# Empty DataFrame
# Columns: [Model Name, KNN K Value, True_Positive, False_Negative, False_Positive, True_Negative, Accuracy, Precision, Recall, F1 Score, Specificity, MCC, ROC_AUC_Score, Balanced Accuracy]
# Index: []

# %%
# Bild KNN Model

from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

import sklearn.metrics as metrics

from sklearn.metrics import roc_curve, roc_auc_score

accuracy = []

for a in range(1, 21, 1):
    
    k = a
    
    # Build the model
    
    ModelKNN = KNeighborsClassifier(n_neighbors=k)
    
    # Train the model
    
    ModelKNN.fit(x_train, y_train)
    
    # Predict the model
    
    y_pred = ModelKNN.predict(x_test)
    y_pred_prob = ModelKNN.predict_proba(x_test)
    
    print('KNN_K_value = ', a)
    
    # Print the model name
    
    print('Model Name: ', ModelKNN)
    
    # confusion matrix in sklearn
    
    from sklearn.metrics import confusion_matrix
    from sklearn.metrics import classification_report
    
    # actual values
    
    actual = y_test
    
    # predicted values
    
    predicted = y_pred
    
    # confusion matrix
    
    matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
    print('Confusion matrix : \n', matrix)
    
    # outcome values order in sklearn
    
    tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
    print('Outcome values : \n', tp, fn, fp, tn)
    
    # classification report for precision, recall f1-score and accuracy
    
    C_Report = classification_report(actual,predicted,labels=[1,0])
    
    print('Classification report : \n', C_Report)
    
    # calculating the metrics
    
    sensitivity = round(tp/(tp+fn), 3);
    specificity = round(tn/(tn+fp), 3);
    accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
    balanced_accuracy = round((sensitivity+specificity)/2, 3);
    
    precision = round(tp/(tp+fp), 3);
    f1Score = round((2*tp/(2*tp + fp + fn)), 3);
    
    # Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1. 
    # A model with a score of +1 is a perfect model and -1 is a poor model
    
    from math import sqrt
    
    mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
    MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)
    
    print('Accuracy :', round(accuracy*100, 2),'%')
    print('Precision :', round(precision*100, 2),'%')
    print('Recall :', round(sensitivity*100,2), '%')
    print('F1 Score :', f1Score)
    print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
    print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
    print('MCC :', MCC)
    
    # Area under ROC curve 
    
    from sklearn.metrics import roc_curve, roc_auc_score
    
    print('roc_auc_score:', round(roc_auc_score(actual, predicted), 3))
    
    # ROC Curve
    
    from sklearn.metrics import roc_auc_score
    from sklearn.metrics import roc_curve
    model_roc_auc = roc_auc_score(actual, predicted)
    fpr, tpr, thresholds = roc_curve(actual, ModelKNN.predict_proba(x_test)[:,1])
    plt.figure()
    # plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
    plt.plot(fpr, tpr, label= 'Classification Model' % model_roc_auc)
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    #plt.savefig('Log_ROC')
    plt.show()
    #------------------------------------------------------------------------------
    new_row = {'Model Name' : ModelKNN,
               'KNN K Value' : a,
               'True_Positive' : tp,
               'False_Negative' : fn,
               'False_Positive' : fp,
               'True_Negative' : tn,
               'Accuracy' : accuracy,
               'Precision' : precision,
               'Recall' : sensitivity,
               'F1 Score' : f1Score,
               'Specificity' : specificity,
               'MCC':MCC,
               'ROC_AUC_Score':roc_auc_score(actual, predicted),
               'Balanced Accuracy':balanced_accuracy}
    KNN_Results = KNN_Results.append(new_row, ignore_index=True)
    #------KNN_Results------------------------------------------------------------------------
# Out:
# KNN_K_value =  1
# Model Name:  KNeighborsClassifier(n_neighbors=1)
# Confusion matrix :
#  [[3226 2923]
#  [1912 8647]]
# Outcome values :
#  3226 2923 1912 8647
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.63      0.52      0.57      6149
#            0       0.75      0.82      0.78     10559
#
#     accuracy                           0.71     16708
#    macro avg       0.69      0.67      0.68     16708
# weighted avg       0.70      0.71      0.70     16708
#
# Accuracy : 71.1 %
# Precision : 62.8 %
# Recall : 52.5 %
# F1 Score : 0.572
# Specificity or True Negative Rate : 81.9 %
# Balanced Accuracy : 67.2 %
# MCC : 0.359
# roc_auc_score: 0.672
# KNN_K_value =  2
# Model Name:  KNeighborsClassifier(n_neighbors=2)
# Confusion matrix :
#  [[1802 4347]
#  [ 935 9624]]
# Outcome values :
#  1802 4347 935 9624
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.66      0.29      0.41      6149
#            0       0.69      0.91      0.78     10559
#
#     accuracy                           0.68     16708
#    macro avg       0.67      0.60      0.60     16708
# weighted avg       0.68      0.68      0.65     16708
#
# Accuracy : 68.4 %
# Precision : 65.8 %
# Recall : 29.3 %
# F1 Score : 0.406
# Specificity or True Negative Rate : 91.1 %
# Balanced Accuracy : 60.2 %
# MCC : 0.266
# roc_auc_score: 0.602
# KNN_K_value =  3
# Model Name:  KNeighborsClassifier(n_neighbors=3)
# Confusion matrix :
#  [[3001 3148]
#  [1761 8798]]
# Outcome values :
#  3001 3148 1761 8798
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.63      0.49      0.55      6149
#            0       0.74      0.83      0.78     10559
#
#     accuracy                           0.71     16708
#    macro avg       0.68      0.66      0.67     16708
# weighted avg       0.70      0.71      0.70     16708
#
# Accuracy : 70.6 %
# Precision : 63.0 %
# Recall : 48.8 %
# F1 Score : 0.55
# Specificity or True Negative Rate : 83.3 %
# Balanced Accuracy : 66.0 %
# MCC : 0.343
# roc_auc_score: 0.661
# KNN_K_value =  4
# Model Name:  KNeighborsClassifier(n_neighbors=4)
# Confusion matrix :
#  [[2077 4072]
#  [1033 9526]]
# Outcome values :
#  2077 4072 1033 9526
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.67      0.34      0.45      6149
#            0       0.70      0.90      0.79     10559
#
#     accuracy                           0.69     16708
#    macro avg       0.68      0.62      0.62     16708
# weighted avg       0.69      0.69      0.66     16708
#
# Accuracy : 69.4 %
# Precision : 66.8 %
# Recall : 33.8 %
# F1 Score : 0.449
# Specificity or True Negative Rate : 90.2 %
# Balanced Accuracy : 62.0 %
# MCC : 0.297
# roc_auc_score: 0.62
# KNN_K_value =  5
# Model Name:  KNeighborsClassifier()
# Confusion matrix :
#  [[3036 3113]
#  [1733 8826]]
# Outcome values :
#  3036 3113 1733 8826
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.64      0.49      0.56      6149
#            0       0.74      0.84      0.78     10559
#
#     accuracy                           0.71     16708
#    macro avg       0.69      0.66      0.67     16708
# weighted avg       0.70      0.71      0.70     16708
#
# Accuracy : 71.0 %
# Precision : 63.7 %
# Recall : 49.4 %
# F1 Score : 0.556
# Specificity or True Negative Rate : 83.6 %
# Balanced Accuracy : 66.5 %
# MCC : 0.352
# roc_auc_score: 0.665
# KNN_K_value =  6
# Model Name:  KNeighborsClassifier(n_neighbors=6)
# Confusion matrix :
#  [[2256 3893]
#  [1178 9381]]
# Outcome values :
#  2256 3893 1178 9381
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.66      0.37      0.47      6149
#            0       0.71      0.89      0.79     10559
#
#     accuracy                           0.70     16708
#    macro avg       0.68      0.63      0.63     16708
# weighted avg       0.69      0.70      0.67     16708
#
# Accuracy : 69.6 %
# Precision : 65.7 %
# Recall : 36.7 %
# F1 Score : 0.471
# Specificity or True Negative Rate : 88.8 %
# Balanced Accuracy : 62.8 %
# MCC : 0.305
# roc_auc_score: 0.628
# KNN_K_value =  7
# Model Name:  KNeighborsClassifier(n_neighbors=7)
# Confusion matrix :
#  [[2973 3176]
#  [1648 8911]]
# Outcome values :
#  2973 3176 1648 8911
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.64      0.48      0.55      6149
#            0       0.74      0.84      0.79     10559
#
#     accuracy                           0.71     16708
#    macro avg       0.69      0.66      0.67     16708
# weighted avg       0.70      0.71      0.70     16708
#
# Accuracy : 71.1 %
# Precision : 64.3 %
# Recall : 48.3 %
# F1 Score : 0.552
# Specificity or True Negative Rate : 84.4 %
# Balanced Accuracy : 66.4 %
# MCC : 0.353
# roc_auc_score: 0.664
# KNN_K_value =  8
# Model Name:  KNeighborsClassifier(n_neighbors=8)
# Confusion matrix :
#  [[2289 3860]
#  [1181 9378]]
# Outcome values :
#  2289 3860 1181 9378
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.66      0.37      0.48      6149
#            0       0.71      0.89      0.79     10559
#
#     accuracy                           0.70     16708
#    macro avg       0.68      0.63      0.63     16708
# weighted avg       0.69      0.70      0.67     16708
#
# Accuracy : 69.8 %
# Precision : 66.0 %
# Recall : 37.2 %
# F1 Score : 0.476
# Specificity or True Negative Rate : 88.8 %
# Balanced Accuracy : 63.0 %
# MCC : 0.31
# roc_auc_score: 0.63
# KNN_K_value =  9
# Model Name:  KNeighborsClassifier(n_neighbors=9)
# Confusion matrix :
#  [[2909 3240]
#  [1621 8938]]
# Outcome values :
#  2909 3240 1621 8938
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.64      0.47      0.54      6149
#            0       0.73      0.85      0.79     10559
#
#     accuracy                           0.71     16708
#    macro avg       0.69      0.66      0.67     16708
# weighted avg       0.70      0.71      0.70     16708
#
# Accuracy : 70.9 %
# Precision : 64.2 %
# Recall : 47.3 %
# F1 Score : 0.545
# Specificity or True Negative Rate : 84.6 %
# Balanced Accuracy : 66.0 %
# MCC : 0.347
# roc_auc_score: 0.66
# KNN_K_value =  10
# Model Name:  KNeighborsClassifier(n_neighbors=10)
# Confusion matrix :
#  [[2375 3774]
#  [1248 9311]]
# Outcome values :
#  2375 3774 1248 9311
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.66      0.39      0.49      6149
#            0       0.71      0.88      0.79     10559
#
#     accuracy                           0.70     16708
#    macro avg       0.68      0.63      0.64     16708
# weighted avg       0.69      0.70      0.68     16708
#
# Accuracy : 69.9 %
# Precision : 65.6 %
# Recall : 38.6 %
# F1 Score : 0.486
# Specificity or True Negative Rate : 88.2 %
# Balanced Accuracy : 63.4 %
# MCC : 0.314
# roc_auc_score: 0.634
# KNN_K_value =  11
# Model Name:  KNeighborsClassifier(n_neighbors=11)
# Confusion matrix :
#  [[2906 3243]
#  [1610 8949]]
# Outcome values :
#  2906 3243 1610 8949
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.64      0.47      0.54      6149
#            0       0.73      0.85      0.79     10559
#
#     accuracy                           0.71     16708
#    macro avg       0.69      0.66      0.67     16708
# weighted avg       0.70      0.71      0.70     16708
#
# Accuracy : 71.0 %
# Precision : 64.3 %
# Recall : 47.3 %
# F1 Score : 0.545
# Specificity or True Negative Rate : 84.8 %
# Balanced Accuracy : 66.0 %
# MCC : 0.348
# roc_auc_score: 0.66
# KNN_K_value =  12
# Model Name:  KNeighborsClassifier(n_neighbors=12)
# Confusion matrix :
#  [[2429 3720]
#  [1260 9299]]
# Outcome values :
#  2429 3720 1260 9299
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.66      0.40      0.49      6149
#            0       0.71      0.88      0.79     10559
#
#     accuracy                           0.70     16708
#    macro avg       0.69      0.64      0.64     16708
# weighted avg       0.69      0.70      0.68     16708
#
# Accuracy : 70.2 %
# Precision : 65.8 %
# Recall : 39.5 %
# F1 Score : 0.494
# Specificity or True Negative Rate : 88.1 %
# Balanced Accuracy : 63.8 %
# MCC : 0.321
# roc_auc_score: 0.638
# KNN_K_value =  13
# Model Name:  KNeighborsClassifier(n_neighbors=13)
# Confusion matrix :
#  [[2939 3210]
#  [1605 8954]]
# Outcome values :
#  2939 3210 1605 8954
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.65      0.48      0.55      6149
#            0       0.74      0.85      0.79     10559
#
#     accuracy                           0.71     16708
#    macro avg       0.69      0.66      0.67     16708
# weighted avg       0.70      0.71      0.70     16708
#
# Accuracy : 71.2 %
# Precision : 64.7 %
# Recall : 47.8 %
# F1 Score : 0.55
# Specificity or True Negative Rate : 84.8 %
# Balanced Accuracy : 66.3 %
# MCC : 0.353
# roc_auc_score: 0.663
# KNN_K_value =  14
# Model Name:  KNeighborsClassifier(n_neighbors=14)
# Confusion matrix :
#  [[2472 3677]
#  [1276 9283]]
# Outcome values :
#  2472 3677 1276 9283
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.66      0.40      0.50      6149
#            0       0.72      0.88      0.79     10559
#
#     accuracy                           0.70     16708
#    macro avg       0.69      0.64      0.64     16708
# weighted avg       0.70      0.70      0.68     16708
#
# Accuracy : 70.4 %
# Precision : 66.0 %
# Recall : 40.2 %
# F1 Score : 0.5
# Specificity or True Negative Rate : 87.9 %
# Balanced Accuracy : 64.1 %
# MCC : 0.325
# roc_auc_score: 0.641
# KNN_K_value =  15
# Model Name:  KNeighborsClassifier(n_neighbors=15)
# Confusion matrix :
#  [[2939 3210]
#  [1593 8966]]
# Outcome values :
#  2939 3210 1593 8966
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.65      0.48      0.55      6149
#            0       0.74      0.85      0.79     10559
#
#     accuracy                           0.71     16708
#    macro avg       0.69      0.66      0.67     16708
# weighted avg       0.70      0.71      0.70     16708
#
# Accuracy : 71.3 %
# Precision : 64.8 %
# Recall : 47.8 %
# F1 Score : 0.55
# Specificity or True Negative Rate : 84.9 %
# Balanced Accuracy : 66.4 %
# MCC : 0.355
# roc_auc_score: 0.664
# KNN_K_value =  16
# Model Name:  KNeighborsClassifier(n_neighbors=16)
# Confusion matrix :
#  [[2531 3618]
#  [1290 9269]]
# Outcome values :
#  2531 3618 1290 9269
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.66      0.41      0.51      6149
#            0       0.72      0.88      0.79     10559
#
#     accuracy                           0.71     16708
#    macro avg       0.69      0.64      0.65     16708
# weighted avg       0.70      0.71      0.69     16708
#
# Accuracy : 70.6 %
# Precision : 66.2 %
# Recall : 41.2 %
# F1 Score : 0.508
# Specificity or True Negative Rate : 87.8 %
# Balanced Accuracy : 64.5 %
# MCC : 0.332
# roc_auc_score: 0.645
# KNN_K_value =  17
# Model Name:  KNeighborsClassifier(n_neighbors=17)
# Confusion matrix :
#  [[2919 3230]
#  [1571 8988]]
# Outcome values :
#  2919 3230 1571 8988
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.65      0.47      0.55      6149
#            0       0.74      0.85      0.79     10559
#
#     accuracy                           0.71     16708
#    macro avg       0.69      0.66      0.67     16708
# weighted avg       0.70      0.71      0.70     16708
#
# Accuracy : 71.3 %
# Precision : 65.0 %
# Recall : 47.5 %
# F1 Score : 0.549
# Specificity or True Negative Rate : 85.1 %
# Balanced Accuracy : 66.3 %
# MCC : 0.355
# roc_auc_score: 0.663
# KNN_K_value =  18
# Model Name:  KNeighborsClassifier(n_neighbors=18)
# Confusion matrix :
#  [[2566 3583]
#  [1298 9261]]
# Outcome values :
#  2566 3583 1298 9261
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.66      0.42      0.51      6149
#            0       0.72      0.88      0.79     10559
#
#     accuracy                           0.71     16708
#    macro avg       0.69      0.65      0.65     16708
# weighted avg       0.70      0.71      0.69     16708
#
# Accuracy : 70.8 %
# Precision : 66.4 %
# Recall : 41.7 %
# F1 Score : 0.513
# Specificity or True Negative Rate : 87.7 %
# Balanced Accuracy : 64.7 %
# MCC : 0.337
# roc_auc_score: 0.647
# KNN_K_value =  19
# Model Name:  KNeighborsClassifier(n_neighbors=19)
# Confusion matrix :
#  [[2948 3201]
#  [1596 8963]]
# Outcome values :
#  2948 3201 1596 8963
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.65      0.48      0.55      6149
#            0       0.74      0.85      0.79     10559
#
#     accuracy                           0.71     16708
#    macro avg       0.69      0.66      0.67     16708
# weighted avg       0.70      0.71      0.70     16708
#
# Accuracy : 71.3 %
# Precision : 64.9 %
# Recall : 47.9 %
# F1 Score : 0.551
# Specificity or True Negative Rate : 84.9 %
# Balanced Accuracy : 66.4 %
# MCC : 0.356
# roc_auc_score: 0.664
# KNN_K_value =  20
# Model Name:  KNeighborsClassifier(n_neighbors=20)
# Confusion matrix :
#  [[2619 3530]
#  [1323 9236]]
# Outcome values :
#  2619 3530 1323 9236
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.66      0.43      0.52      6149
#            0       0.72      0.87      0.79     10559
#
#     accuracy                           0.71     16708
#    macro avg       0.69      0.65      0.66     16708
# weighted avg       0.70      0.71      0.69     16708
#
# Accuracy : 71.0 %
# Precision : 66.4 %
# Recall : 42.6 %
# F1 Score : 0.519
# Specificity or True Negative Rate : 87.5 %
# Balanced Accuracy : 65.0 %
# MCC : 0.341
# roc_auc_score: 0.65

# %%
KNN_Results
# Out:
#                               Model Name KNN K Value True_Positive  \
# 0    KNeighborsClassifier(n_neighbors=1)           1          3226
# 1    KNeighborsClassifier(n_neighbors=2)           2          1802
# 2    KNeighborsClassifier(n_neighbors=3)           3          3001
# 3    KNeighborsClassifier(n_neighbors=4)           4          2077
# 4                 KNeighborsClassifier()           5          3036
# 5    KNeighborsClassifier(n_neighbors=6)           6          2256
# 6    KNeighborsClassifier(n_neighbors=7)           7          2973
# 7    KNeighborsClassifier(n_neighbors=8)           8          2289
# 8    KNeighborsClassifier(n_neighbors=9)           9          2909
# 9   KNeighborsClassifier(n_neighbors=10)          10          2375
# 10  KNeighborsClassifier(n_neighbors=11)          11          2906
# 11  KNeighborsClassifier(n_neighbors=12)          12          2429
# 12  KNeighborsClassifier(n_neighbors=13)          13          2939
# 13  KNeighborsClassifier(n_neighbors=14)          14          2472
# 14  KNeighborsClassifier(n_neighbors=15)          15          2939
# 15  KNeighborsClassifier(n_neighbors=16)          16          2531
# 16  KNeighborsClassifier(n_neighbors=17)          17          2919
# 17  KNeighborsClassifier(n_neighbors=18)          18          2566
# 18  KNeighborsClassifier(n_neighbors=19)          19          2948
# 19  KNeighborsClassifier(n_neighbors=20)          20          2619
#
#    False_Negative False_Positive True_Negative  Accuracy  Precision  Recall  \
# 0            2923           1912          8647     0.711      0.628   0.525
# 1            4347            935          9624     0.684      0.658   0.293
# 2            3148           1761          8798     0.706      0.630   0.488
# 3            4072           1033          9526     0.694      0.668   0.338
# 4            3113           1733          8826     0.710      0.637   0.494
# 5            3893           1178          9381     0.696      0.657   0.367
# 6            3176           1648          8911     0.711      0.643   0.483
# 7            3860           1181          9378     0.698      0.660   0.372
# 8            3240           1621          8938     0.709      0.642   0.473
# 9            3774           1248          9311     0.699      0.656   0.386
# 10           3243           1610          8949     0.710      0.643   0.473
# 11           3720           1260          9299     0.702      0.658   0.395
# 12           3210           1605          8954     0.712      0.647   0.478
# 13           3677           1276          9283     0.704      0.660   0.402
# 14           3210           1593          8966     0.713      0.648   0.478
# 15           3618           1290          9269     0.706      0.662   0.412
# 16           3230           1571          8988     0.713      0.650   0.475
# 17           3583           1298          9261     0.708      0.664   0.417
# 18           3201           1596          8963     0.713      0.649   0.479
# 19           3530           1323          9236     0.710      0.664   0.426
#
#     F1 Score  Specificity    MCC  ROC_AUC_Score  Balanced Accuracy
# 0      0.572        0.819  0.359       0.671780              0.672
# 1      0.406        0.911  0.266       0.602253              0.602
# 2      0.550        0.833  0.343       0.660635              0.660
# 3      0.449        0.902  0.297       0.619974              0.620
# 4      0.556        0.836  0.352       0.664807              0.665
# 5      0.471        0.888  0.305       0.627663              0.628
# 6      0.552        0.844  0.353       0.663709              0.664
# 7      0.476        0.888  0.310       0.630204              0.630
# 8      0.545        0.846  0.347       0.659783              0.660
# 9      0.486        0.882  0.314       0.634024              0.634
# 10     0.545        0.848  0.348       0.660060              0.660
# 11     0.494        0.881  0.321       0.637847              0.638
# 12     0.550        0.848  0.353       0.662980              0.663
# 13     0.500        0.879  0.325       0.640586              0.641
# 14     0.550        0.849  0.355       0.663549              0.664
# 15     0.508        0.878  0.332       0.644720              0.645
# 16     0.549        0.851  0.355       0.662964              0.663
# 17     0.513        0.877  0.337       0.647188              0.647
# 18     0.551        0.849  0.356       0.664138              0.664
# 19     0.519        0.875  0.341       0.650313              0.650

# %% [markdown]
# # SVM ALGORITHM

# %%
EMResults=pd.read_csv(r"C:\Users\SATISH VARMA\Downloads\EMResults (1).csv",header=0)
EMResults.head()
# Out:
# Empty DataFrame
# Columns: [Model Name, True_Positive, False_Negative, False_Positive, True_Negative, Accuracy, Precision, Recall, F1 Score, Specificity, MCC, ROC_AUC_Score, Balanced Accuracy]
# Index: []

# %% [markdown]
# # SVM - Linear Kernel

# %%
# Training the SVM algorithm with train dataset

from sklearn.svm import SVC

ModelSVM1 = SVC(C=1.0, kernel='linear', degree=3, gamma='scale', coef0=0.0, shrinking=True, 
                probability=True, tol=0.001, cache_size=200, class_weight=None, verbose=False, 
                max_iter=- 1, decision_function_shape='ovr', break_ties=False, random_state=None)

# Train the model with train data 

ModelSVM1 = ModelSVM1.fit(x_train, y_train)

# Predict the model with test data set

y_pred = ModelSVM1.predict(x_test)
y_pred_prob = ModelSVM1.predict_proba(x_test)

# Print the model name
    
print('Model Name: ', "SVM - Linear")

# Confusion matrix in sklearn

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# actual values

actual = y_test

# predicted values

predicted = y_pred

# confusion matrix

matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
print('Confusion matrix : \n', matrix)

# outcome values order in sklearn

tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn)

# classification report for precision, recall f1-score and accuracy

C_Report = classification_report(actual,predicted,labels=[1,0])

print('Classification report : \n', C_Report)

# calculating the metrics

sensitivity = round(tp/(tp+fn), 3);
specificity = round(tn/(tn+fp), 3);
accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
balanced_accuracy = round((sensitivity+specificity)/2, 3);
precision = round(tp/(tp+fp), 3);
f1Score = round((2*tp/(2*tp + fp + fn)), 3);

# Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1. 
# A model with a score of +1 is a perfect model and -1 is a poor model

from math import sqrt

mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

print('Accuracy :', round(accuracy*100, 2),'%')
print('Precision :', round(precision*100, 2),'%')
print('Recall :', round(sensitivity*100,2), '%')
print('F1 Score :', f1Score)
print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
print('MCC :', MCC)

# Area under ROC curve 

from sklearn.metrics import roc_curve, roc_auc_score

print('roc_auc_score:', round(roc_auc_score(actual, predicted), 3))

# ROC Curve

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
model_roc_auc = roc_auc_score(actual, predicted)
fpr, tpr, thresholds = roc_curve(actual,ModelSVM1.predict_proba(x_test)[:,1])
plt.figure()
# plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot(fpr, tpr, label= 'Classification Model' % model_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show() 
print('-----------------------------------------------------------------------------------------------------')
#---
new_row = {'Model Name' : "SVM - Linear",
            'True_Positive' : tp, 
            'False_Negative' : fn, 
            'False_Positive' : fp,
            'True_Negative' : tn,
            'Accuracy' : accuracy,
            'Precision' : precision,
            'Recall' : sensitivity,
            'F1 Score' : f1Score,
            'Specificity' : specificity,
            'MCC':MCC,
            'ROC_AUC_Score':roc_auc_score(actual, predicted),
            'Balanced Accuracy':balanced_accuracy}
EMResults = EMResults.append(new_row, ignore_index=True)
# Out:
# Model Name:  SVM - Linear
# Confusion matrix :
#  [[2636 3513]
#  [1180 9379]]
# Outcome values :
#  2636 3513 1180 9379
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.69      0.43      0.53      6149
#            0       0.73      0.89      0.80     10559
#
#     accuracy                           0.72     16708
#    macro avg       0.71      0.66      0.66     16708
# weighted avg       0.71      0.72      0.70     16708
#
# Accuracy : 71.9 %
# Precision : 69.1 %
# Recall : 42.9 %
# F1 Score : 0.529
# Specificity or True Negative Rate : 88.8 %
# Balanced Accuracy : 65.8 %
# MCC : 0.364
# roc_auc_score: 0.658
# -----------------------------------------------------------------------------------------------------

# %%
EMResults
# Out:
#      Model Name True_Positive False_Negative False_Positive True_Negative  \
# 0  SVM - Linear          2636           3513           1180          9379
#
#    Accuracy  Precision  Recall  F1 Score  Specificity    MCC  ROC_AUC_Score  \
# 0     0.719      0.691   0.429     0.529        0.888  0.364       0.658467
#
#    Balanced Accuracy
# 0              0.658

# %% [markdown]
# # Polynomial Kernel

# %%
# Training the SVM algorithm

from sklearn.svm import SVC

ModelSVMPoly = SVC(kernel='poly', degree=2, probability=True)

# Train the model

ModelSVMPoly.fit(x_train, y_train)

# Predict the model with test data set

y_pred = ModelSVMPoly.predict(x_test)
y_pred_prob = ModelSVMPoly.predict_proba(x_test)

# Print the model name
    
print('Model Name: ', "SVM - Polynominal")

# Confusion matrix in sklearn

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# actual values

actual = y_test

# predicted values

predicted = y_pred

# confusion matrix

matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
print('Confusion matrix : \n', matrix)

# outcome values order in sklearn

tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn)

# classification report for precision, recall f1-score and accuracy

C_Report = classification_report(actual,predicted,labels=[1,0])

print('Classification report : \n', C_Report)

# calculating the metrics

sensitivity = round(tp/(tp+fn), 3);
specificity = round(tn/(tn+fp), 3);
accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
balanced_accuracy = round((sensitivity+specificity)/2, 3);
precision = round(tp/(tp+fp), 3);
f1Score = round((2*tp/(2*tp + fp + fn)), 3);

# Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1. 
# A model with a score of +1 is a perfect model and -1 is a poor model

from math import sqrt

mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

print('Accuracy :', round(accuracy*100, 2),'%')
print('Precision :', round(precision*100, 2),'%')
print('Recall :', round(sensitivity*100,2), '%')
print('F1 Score :', f1Score)
print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
print('MCC :', MCC)

# Area under ROC curve 

from sklearn.metrics import roc_curve, roc_auc_score

print('roc_auc_score:', round(roc_auc_score(y_test, y_pred), 3))

# ROC Curve

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, y_pred)
fpr, tpr, thresholds = roc_curve(y_test,ModelSVMPoly.predict_proba(x_test)[:,1])
plt.figure()
# plt.plot
plt.plot(fpr, tpr, label= 'Classification Model' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show() 
print('-----------------------------------------------------------------------------------------------------')
#---
new_row = {'Model Name' : "SVM - Polynominal",
            'True_Positive' : tp, 
            'False_Negative' : fn, 
            'False_Positive' : fp,
            'True_Negative' : tn,
            'Accuracy' : accuracy,
            'Precision' : precision,
            'Recall' : sensitivity,
            'F1 Score' : f1Score,
            'Specificity' : specificity,
            'MCC':MCC,
            'ROC_AUC_Score':roc_auc_score(actual, predicted),
            'Balanced Accuracy':balanced_accuracy}
EMResults = EMResults.append(new_row, ignore_index=True)
#-----------------------------------------------------------------------------------------------
# Out:
# Model Name:  SVM - Polynominal
# Confusion matrix :
#  [[2733 3416]
#  [1171 9388]]
# Outcome values :
#  2733 3416 1171 9388
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.70      0.44      0.54      6149
#            0       0.73      0.89      0.80     10559
#
#     accuracy                           0.73     16708
#    macro avg       0.72      0.67      0.67     16708
# weighted avg       0.72      0.73      0.71     16708
#
# Accuracy : 72.5 %
# Precision : 70.0 %
# Recall : 44.4 %
# F1 Score : 0.544
# Specificity or True Negative Rate : 88.9 %
# Balanced Accuracy : 66.6 %
# MCC : 0.38
# roc_auc_score: 0.667
# -----------------------------------------------------------------------------------------------------

# %%
EMResults
# Out:
#           Model Name True_Positive False_Negative False_Positive  \
# 0       SVM - Linear          2636           3513           1180
# 1  SVM - Polynominal          2733           3416           1171
#
#   True_Negative  Accuracy  Precision  Recall  F1 Score  Specificity    MCC  \
# 0          9379     0.719      0.691   0.429     0.529        0.888  0.364
# 1          9388     0.725      0.700   0.444     0.544        0.889  0.380
#
#    ROC_AUC_Score  Balanced Accuracy
# 0       0.658467              0.658
# 1       0.666781              0.666

# %% [markdown]
# # Gaussian kernel

# %%
# Training the SVM algorithm

from sklearn.svm import SVC

ModelSVMGaussian = SVC(kernel='rbf', random_state = 42, class_weight='balanced', probability=True)

# Train the model

ModelSVMGaussian.fit(x_train, y_train)

# Predict the model with test data set

y_pred = ModelSVMGaussian.predict(x_test)
y_pred_prob = ModelSVMGaussian.predict_proba(x_test)

# Confusion matrix in sklearn

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# Print the model name
    
print('Model Name: ', "SVM - Gaussian")

# actual values

actual = y_test

# predicted values

predicted = y_pred

# confusion matrix

matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
print('Confusion matrix : \n', matrix)

# outcome values order in sklearn

tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn)

# classification report for precision, recall f1-score and accuracy

C_Report = classification_report(actual,predicted,labels=[1,0])

print('Classification report : \n', C_Report)

# calculating the metrics

sensitivity = round(tp/(tp+fn), 3);
specificity = round(tn/(tn+fp), 3);
accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
balanced_accuracy = round((sensitivity+specificity)/2, 3);
precision = round(tp/(tp+fp), 3);
f1Score = round((2*tp/(2*tp + fp + fn)), 3);

# Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1. 
# A model with a score of +1 is a perfect model and -1 is a poor model

from math import sqrt

mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

print('Accuracy :', round(accuracy*100, 2),'%')
print('Precision :', round(precision*100, 2),'%')
print('Recall :', round(sensitivity*100,2), '%')
print('F1 Score :', f1Score)
print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
print('MCC :', MCC)

# Area under ROC curve 

from sklearn.metrics import roc_curve, roc_auc_score

print('roc_auc_score:', round(roc_auc_score(y_test, y_pred), 3))

# ROC Curve

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, y_pred)
fpr, tpr, thresholds = roc_curve(y_test,ModelSVMGaussian.predict_proba(x_test)[:,1])
plt.figure()
# plt.plot
plt.plot(fpr, tpr, label= 'Classification Model' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show() 
print('-----------------------------------------------------------------------------------------------------')
#---
new_row = {'Model Name' : "SVM - Gaussian",
            'True_Positive' : tp, 
            'False_Negative' : fn, 
            'False_Positive' : fp,
            'True_Negative' : tn,
            'Accuracy' : accuracy,
            'Precision' : precision,
            'Recall' : sensitivity,
            'F1 Score' : f1Score,
            'Specificity' : specificity,
            'MCC':MCC,
            'ROC_AUC_Score':roc_auc_score(actual, predicted),
            'Balanced Accuracy':balanced_accuracy}
EMResults = EMResults.append(new_row, ignore_index=True)
#---------------------------------------------------------------------------------------------------------------
# Out:
# Model Name:  SVM - Gaussian
# Confusion matrix :
#  [[5876  273]
#  [4738 5821]]
# Outcome values :
#  5876 273 4738 5821
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.55      0.96      0.70      6149
#            0       0.96      0.55      0.70     10559
#
#     accuracy                           0.70     16708
#    macro avg       0.75      0.75      0.70     16708
# weighted avg       0.81      0.70      0.70     16708
#
# Accuracy : 70.0 %
# Precision : 55.4 %
# Recall : 95.6 %
# F1 Score : 0.701
# Specificity or True Negative Rate : 55.1 %
# Balanced Accuracy : 75.4 %
# MCC : 0.508
# roc_auc_score: 0.753
# -----------------------------------------------------------------------------------------------------

# %%
EMResults
# Out:
#           Model Name True_Positive False_Negative False_Positive  \
# 0       SVM - Linear          2636           3513           1180
# 1  SVM - Polynominal          2733           3416           1171
# 2     SVM - Gaussian          5876            273           4738
#
#   True_Negative  Accuracy  Precision  Recall  F1 Score  Specificity    MCC  \
# 0          9379     0.719      0.691   0.429     0.529        0.888  0.364
# 1          9388     0.725      0.700   0.444     0.544        0.889  0.380
# 2          5821     0.700      0.554   0.956     0.701        0.551  0.508
#
#    ROC_AUC_Score  Balanced Accuracy
# 0       0.658467              0.658
# 1       0.666781              0.666
# 2       0.753443              0.754

# %% [markdown]
# # sigmoid kernel

# %%
# Training the SVM algorithm

from sklearn.svm import SVC

ModelSVMSig = SVC(kernel='sigmoid', random_state = 42, class_weight='balanced', probability=True)

# Train the model

ModelSVMSig.fit(x_train, y_train)

# Predict the model with test data set

y_pred = ModelSVMSig.predict(x_test)
y_pred_prob = ModelSVMSig.predict_proba(x_test)

# Print the model name
    
print('Model Name: ', "SVM - Sigmoid")

# Confusion matrix in sklearn

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# actual values

actual = y_test

# predicted values

predicted = y_pred

# confusion matrix

matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
print('Confusion matrix : \n', matrix)

# outcome values order in sklearn

tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn)

# classification report for precision, recall f1-score and accuracy

C_Report = classification_report(actual,predicted,labels=[1,0])

print('Classification report : \n', C_Report)

# calculating the metrics

sensitivity = round(tp/(tp+fn), 3);
specificity = round(tn/(tn+fp), 3);
accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
balanced_accuracy = round((sensitivity+specificity)/2, 3);
precision = round(tp/(tp+fp), 3);
f1Score = round((2*tp/(2*tp + fp + fn)), 3);

# Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1. 
# A model with a score of +1 is a perfect model and -1 is a poor model

from math import sqrt

mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

print('Accuracy :', round(accuracy*100, 2),'%')
print('Precision :', round(precision*100, 2),'%')
print('Recall :', round(sensitivity*100,2), '%')
print('F1 Score :', f1Score)
print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
print('MCC :', MCC)

# Area under ROC curve 

from sklearn.metrics import roc_curve, roc_auc_score

print('roc_auc_score:', round(roc_auc_score(y_test, y_pred), 3))

# ROC Curve

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, y_pred)
fpr, tpr, thresholds = roc_curve(y_test,ModelSVMSig.predict_proba(x_test)[:,1])
plt.figure()
# plt.plot
plt.plot(fpr, tpr, label= 'Classification Model' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show() 
print('-----------------------------------------------------------------------------------------------------')
#---
new_row = {'Model Name' : "SVM - Sigmoid",
            'True_Positive' : tp, 
            'False_Negative' : fn, 
            'False_Positive' : fp,
            'True_Negative' : tn,
            'Accuracy' : accuracy,
            'Precision' : precision,
            'Recall' : sensitivity,
            'F1 Score' : f1Score,
            'Specificity' : specificity,
            'MCC':MCC,
            'ROC_AUC_Score':roc_auc_score(actual, predicted),
            'Balanced Accuracy':balanced_accuracy}
EMResults = EMResults.append(new_row, ignore_index=True)
#-----------------------------------------------------------------------------------------------------------
# Out:
# Model Name:  SVM - Sigmoid
# Confusion matrix :
#  [[3029 3120]
#  [5776 4783]]
# Outcome values :
#  3029 3120 5776 4783
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.34      0.49      0.41      6149
#            0       0.61      0.45      0.52     10559
#
#     accuracy                           0.47     16708
#    macro avg       0.47      0.47      0.46     16708
# weighted avg       0.51      0.47      0.48     16708
#
# Accuracy : 46.8 %
# Precision : 34.4 %
# Recall : 49.3 %
# F1 Score : 0.405
# Specificity or True Negative Rate : 45.3 %
# Balanced Accuracy : 47.3 %
# MCC : -0.053
# roc_auc_score: 0.473
# -----------------------------------------------------------------------------------------------------

# %%
EMResults
# Out:
#           Model Name True_Positive False_Negative False_Positive  \
# 0       SVM - Linear          2636           3513           1180
# 1  SVM - Polynominal          2733           3416           1171
# 2     SVM - Gaussian          5876            273           4738
# 3      SVM - Sigmoid          3029           3120           5776
#
#   True_Negative  Accuracy  Precision  Recall  F1 Score  Specificity    MCC  \
# 0          9379     0.719      0.691   0.429     0.529        0.888  0.364
# 1          9388     0.725      0.700   0.444     0.544        0.889  0.380
# 2          5821     0.700      0.554   0.956     0.701        0.551  0.508
# 3          4783     0.468      0.344   0.493     0.405        0.453 -0.053
#
#    ROC_AUC_Score  Balanced Accuracy
# 0       0.658467              0.658
# 1       0.666781              0.666
# 2       0.753443              0.754
# 3       0.472789              0.473

# %% [markdown]
# # compare the classification algorithms

# %%
# Build the Calssification models and compare the results

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB

# Create objects of classification algorithm with default hyper-parameters

ModelLR = LogisticRegression()
ModelDC = DecisionTreeClassifier()
ModelRF = RandomForestClassifier()
ModelET = ExtraTreesClassifier()
ModelKNN = KNeighborsClassifier(n_neighbors=1)
ModelSVM = SVC(kernel='poly', degree=2, probability=True)
ModelGNB = GaussianNB()

# Evalution matrix for all the algorithms

MM = [ModelLR, ModelDC, ModelRF, ModelET, ModelKNN, ModelSVM, ModelGNB]
for models in MM:

    # Fit the model

    models.fit(x_train, y_train)

    # Prediction

    y_pred = models.predict(x_test)
    y_pred_prob = models.predict_proba(x_test)

    # Print the model name

    print('Model Name: ', models)

    # confusion matrix in sklearn

    from sklearn.metrics import confusion_matrix
    from sklearn.metrics import classification_report

    # actual values

    actual = y_test

    # predicted values

    predicted = y_pred

    # confusion matrix

    matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
    print('Confusion matrix : \n', matrix)

    # outcome values order in sklearn

    tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
    print('Outcome values : \n', tp, fn, fp, tn)

    # classification report for precision, recall f1-score and accuracy

    C_Report = classification_report(actual,predicted,labels=[1,0])

    print('Classification report : \n', C_Report)

    # calculating the metrics

    sensitivity = round(tp/(tp+fn), 3);
    specificity = round(tn/(tn+fp), 3);
    accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
    balanced_accuracy = round((sensitivity+specificity)/2, 3);

    precision = round(tp/(tp+fp), 3);
    f1Score = round((2*tp/(2*tp + fp + fn)), 3);

    # Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1.
    # A model with a score of +1 is a perfect model and -1 is a poor model

    from math import sqrt

    mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
    MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

    print('Accuracy :', round(accuracy*100, 2),'%')
    print('Precision :', round(precision*100, 2),'%')
    print('Recall :', round(sensitivity*100,2), '%')
    print('F1 Score :', f1Score)
    print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
    print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
    print('MCC :', MCC)

    # Area under ROC curve

    from sklearn.metrics import roc_curve, roc_auc_score

    print('roc_auc_score:', round(roc_auc_score(actual, predicted), 3))

    # ROC Curve

    from sklearn.metrics import roc_auc_score
    from sklearn.metrics import roc_curve
    logit_roc_auc = roc_auc_score(actual, predicted)
    fpr, tpr, thresholds = roc_curve(actual, models.predict_proba(x_test)[:,1])
    plt.figure()
    # plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
    plt.plot(fpr, tpr, label= 'Classification Model' % logit_roc_auc)
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    plt.savefig('Log_ROC')
    plt.show()
    print('-----------------------------------------------------------------------------------------------------')
    #----------------------------------------------------------------------------------------------------------
    new_row = {'Model Name' : models,
               'True_Positive' : tp,
               'False_Negative' : fn,
               'False_Positive' : fp,
               'True_Negative' : tn,
               'Accuracy' : accuracy,
               'Precision' : precision,
               'Recall' : sensitivity,
               'F1 Score' : f1Score,
               'Specificity' : specificity,
               'MCC':MCC,
               'ROC_AUC_Score':roc_auc_score(actual, predicted),
               'Balanced Accuracy':balanced_accuracy}
    EMResults = EMResults.append(new_row, ignore_index=True)
    #----------------------------------------------------------------------------------------------------------
# Out:
# Model Name:  LogisticRegression()
# Confusion matrix :
#  [[1988 4161]
#  [ 728 9831]]
# Outcome values :
#  1988 4161 728 9831
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.73      0.32      0.45      6149
#            0       0.70      0.93      0.80     10559
#
#     accuracy                           0.71     16708
#    macro avg       0.72      0.63      0.62     16708
# weighted avg       0.71      0.71      0.67     16708
#
# Accuracy : 70.7 %
# Precision : 73.2 %
# Recall : 32.3 %
# F1 Score : 0.449
# Specificity or True Negative Rate : 93.1 %
# Balanced Accuracy : 62.7 %
# MCC : 0.332
# roc_auc_score: 0.627
# -----------------------------------------------------------------------------------------------------
# Model Name:  DecisionTreeClassifier()
# Confusion matrix :
#  [[3279 2870]
#  [3231 7328]]
# Outcome values :
#  3279 2870 3231 7328
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.50      0.53      0.52      6149
#            0       0.72      0.69      0.71     10559
#
#     accuracy                           0.63     16708
#    macro avg       0.61      0.61      0.61     16708
# weighted avg       0.64      0.63      0.64     16708
#
# Accuracy : 63.5 %
# Precision : 50.4 %
# Recall : 53.3 %
# F1 Score : 0.518
# Specificity or True Negative Rate : 69.4 %
# Balanced Accuracy : 61.3 %
# MCC : 0.225
# roc_auc_score: 0.614
# -----------------------------------------------------------------------------------------------------
# Model Name:  RandomForestClassifier()
# Confusion matrix :
#  [[2960 3189]
#  [1134 9425]]
# Outcome values :
#  2960 3189 1134 9425
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.72      0.48      0.58      6149
#            0       0.75      0.89      0.81     10559
#
#     accuracy                           0.74     16708
#    macro avg       0.74      0.69      0.70     16708
# weighted avg       0.74      0.74      0.73     16708
#
# Accuracy : 74.1 %
# Precision : 72.3 %
# Recall : 48.1 %
# F1 Score : 0.578
# Specificity or True Negative Rate : 89.3 %
# Balanced Accuracy : 68.7 %
# MCC : 0.419
# roc_auc_score: 0.687
# -----------------------------------------------------------------------------------------------------
# Model Name:  ExtraTreesClassifier()
# Confusion matrix :
#  [[3274 2875]
#  [1325 9234]]
# Outcome values :
#  3274 2875 1325 9234
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.71      0.53      0.61      6149
#            0       0.76      0.87      0.81     10559
#
#     accuracy                           0.75     16708
#    macro avg       0.74      0.70      0.71     16708
# weighted avg       0.74      0.75      0.74     16708
#
# Accuracy : 74.9 %
# Precision : 71.2 %
# Recall : 53.2 %
# F1 Score : 0.609
# Specificity or True Negative Rate : 87.5 %
# Balanced Accuracy : 70.4 %
# MCC : 0.439
# roc_auc_score: 0.703
# -----------------------------------------------------------------------------------------------------
# Model Name:  KNeighborsClassifier(n_neighbors=1)
# Confusion matrix :
#  [[3226 2923]
#  [1912 8647]]
# Outcome values :
#  3226 2923 1912 8647
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.63      0.52      0.57      6149
#            0       0.75      0.82      0.78     10559
#
#     accuracy                           0.71     16708
#    macro avg       0.69      0.67      0.68     16708
# weighted avg       0.70      0.71      0.70     16708
#
# Accuracy : 71.1 %
# Precision : 62.8 %
# Recall : 52.5 %
# F1 Score : 0.572
# Specificity or True Negative Rate : 81.9 %
# Balanced Accuracy : 67.2 %
# MCC : 0.359
# roc_auc_score: 0.672
# -----------------------------------------------------------------------------------------------------
# Model Name:  SVC(degree=2, kernel='poly', probability=True)
# Confusion matrix :
#  [[2733 3416]
#  [1171 9388]]
# Outcome values :
#  2733 3416 1171 9388
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.70      0.44      0.54      6149
#            0       0.73      0.89      0.80     10559
#
#     accuracy                           0.73     16708
#    macro avg       0.72      0.67      0.67     16708
# weighted avg       0.72      0.73      0.71     16708
#
# Accuracy : 72.5 %
# Precision : 70.0 %
# Recall : 44.4 %
# F1 Score : 0.544
# Specificity or True Negative Rate : 88.9 %
# Balanced Accuracy : 66.6 %
# MCC : 0.38
# roc_auc_score: 0.667
# -----------------------------------------------------------------------------------------------------
# Model Name:  GaussianNB()
# Confusion matrix :
#  [[5013 1136]
#  [3865 6694]]
# Outcome values :
#  5013 1136 3865 6694
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.56      0.82      0.67      6149
#            0       0.85      0.63      0.73     10559
#
#     accuracy                           0.70     16708
#    macro avg       0.71      0.72      0.70     16708
# weighted avg       0.75      0.70      0.71     16708
#
# Accuracy : 70.1 %
# Precision : 56.5 %
# Recall : 81.5 %
# F1 Score : 0.667
# Specificity or True Negative Rate : 63.4 %
# Balanced Accuracy : 72.4 %
# MCC : 0.434
# roc_auc_score: 0.725
# -----------------------------------------------------------------------------------------------------

# %%
EMResults
# Out:
#                                            Model Name True_Positive  \
# 0                                        SVM - Linear          2636
# 1                                   SVM - Polynominal          2733
# 2                                      SVM - Gaussian          5876
# 3                                       SVM - Sigmoid          3029
# 4                                LogisticRegression()          1988
# 5                            DecisionTreeClassifier()          3279
# 6   (DecisionTreeClassifier(max_features='sqrt', r...          2960
# 7   (ExtraTreeClassifier(random_state=744336446), ...          3274
# 8                 KNeighborsClassifier(n_neighbors=1)          3226
# 9      SVC(degree=2, kernel='poly', probability=True)          2733
# 10                                       GaussianNB()          5013
#
#    False_Negative False_Positive True_Negative  Accuracy  Precision  Recall  \
# 0            3513           1180          9379     0.719      0.691   0.429
# 1            3416           1171          9388     0.725      0.700   0.444
# 2             273           4738          5821     0.700      0.554   0.956
# 3            3120           5776          4783     0.468      0.344   0.493
# 4            4161            728          9831     0.707      0.732   0.323
# 5            2870           3231          7328     0.635      0.504   0.533
# 6            3189           1134          9425     0.741      0.723   0.481
# 7            2875           1325          9234     0.749      0.712   0.532
# 8            2923           1912          8647     0.711      0.628   0.525
# 9            3416           1171          9388     0.725      0.700   0.444
# 10           1136           3865          6694     0.701      0.565   0.815
#
#     F1 Score  Specificity    MCC  ROC_AUC_Score  Balanced Accuracy
# 0      0.529        0.888  0.364       0.658467              0.658
# 1      0.544        0.889  0.380       0.666781              0.666
# 2      0.701        0.551  0.508       0.753443              0.754
# 3      0.405        0.453 -0.053       0.472789              0.473
# 4      0.449        0.931  0.332       0.627179              0.627
# 5      0.518        0.694  0.225       0.613631              0.613
# 6      0.578        0.893  0.419       0.686991              0.687
# 7      0.609        0.875  0.439       0.703479              0.704
# 8      0.572        0.819  0.359       0.671780              0.672
# 9      0.544        0.889  0.380       0.666781              0.666
# 10     0.667        0.634  0.434       0.724608              0.724

# %%
y_PredSVM=ModelSVM.predict(x_test)

# %%
#Display the Final result 

Results = pd.DataFrame({'smoking_A':y_test,'smoking_P':y_pred})

#Merge two Dataframes on index of both the dataframes

ResultsFinal = smoke_bk.merge(Results,left_index=True,right_index=True)

# Display 10 records randomly

ResultsFinal.sample(10)
# Out:
#        gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 36290       0   40         160          50       68.0             1.2
# 20340       1   55         170          65       81.8             1.0
# 32392       1   30         165          85       97.0             1.5
# 52350       1   35         175          80       83.0             1.5
# 48904       0   50         155          70       81.0             0.9
# 28167       1   40         170          75       90.0             1.5
# 17418       1   40         175          80       95.0             0.9
# 20118       1   35         170          65       81.5             1.2
# 36807       1   60         160          60       83.0             0.6
# 13907       1   55         160          40       62.0             1.2
#
#        eyesight(right)  hearing(left)  hearing(right)  systolic  relaxation  \
# 36290              1.2            1.0             1.0     119.0        79.0
# 20340              1.0            1.0             1.0     121.0        89.0
# 32392              1.5            1.0             1.0     120.0        82.0
# 52350              1.2            1.0             1.0     118.0        78.0
# 48904              1.0            1.0             1.0     130.0        90.0
# 28167              1.5            1.0             1.0     140.0        90.0
# 17418              0.9            1.0             1.0     117.0        65.0
# 20118              1.2            1.0             1.0     112.0        72.0
# 36807              1.2            1.0             1.0     141.0        89.0
# 13907              0.9            1.0             1.0     104.0        64.0
#
#        fasting blood sugar  Cholesterol  triglyceride    HDL    LDL  \
# 36290                 80.0        180.0         163.0   63.0   84.0
# 20340                 96.0         99.0          48.0   52.0   50.0
# 32392                 97.0        232.0         131.0   62.0  144.0
# 52350                 93.0        201.0         127.0   59.0  117.0
# 48904                 99.0        218.0         157.0   99.0   87.0
# 28167                 95.0        257.0         211.0   54.0  164.0
# 17418                101.0        191.0         263.0   36.0  102.0
# 20118                 93.0        266.0         234.0   34.0  185.0
# 36807                120.0        271.0          87.0  103.0  150.0
# 13907                 92.0        211.0         116.0   67.0  121.0
#
#        hemoglobin  Urine protein  serum creatinine   AST   ALT    Gtp  oral  \
# 36290        12.6            1.0               0.8  21.0  10.0   18.0     0
# 20340        15.5            1.0               1.1  44.0  52.0   41.0     0
# 32392        15.8            1.0               1.2  17.0  24.0   25.0     0
# 52350        16.5            1.0               1.2  23.0  20.0   14.0     0
# 48904        14.7            1.0               0.7  22.0  10.0   51.0     0
# 28167        16.7            1.0               0.8  25.0  27.0   23.0     0
# 17418        14.7            1.0               1.0  21.0  27.0   29.0     0
# 20118        15.6            1.0               1.5  16.0  15.0   27.0     0
# 36807        14.5            1.0               0.8  41.0  42.0  390.0     0
# 13907        16.1            1.0               1.1  26.0  24.0   36.0     0
#
#        dental caries  tartar  smoking  smoking_A  smoking_P
# 36290              0       0        0          0          0
# 20340              1       0        1          1          1
# 32392              0       1        1          1          1
# 52350              1       1        1          1          1
# 48904              1       1        0          0          0
# 28167              0       0        0          0          1
# 17418              1       1        0          0          1
# 20118              0       0        1          1          0
# 36807              0       1        0          0          1
# 13907              0       0        0          0          0

# %%
# Calculate the %of Error

ResultsFinal['%Error'] = round(((ResultsFinal['smoking_A']-ResultsFinal['smoking_P'])/ResultsFinal['smoking_A'])*100,3)

# %%
ResultsFinal.sample(10)
# Out:
#        gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 33794       1   30         175          70       86.5             1.2
# 20914       0   60         165          70       87.0             0.3
# 7898        1   35         160          70       85.0             0.8
# 8829        0   40         155          65       83.0             0.5
# 46050       0   60         155          55       79.4             1.0
# 54433       1   45         175          90       95.0             0.7
# 21930       1   40         180          85       90.6             1.0
# 43267       1   60         160          65       82.0             0.9
# 16994       0   40         155          65       81.8             1.2
# 31113       0   60         150          70       92.0             0.5
#
#        eyesight(right)  hearing(left)  hearing(right)  systolic  relaxation  \
# 33794              1.2            1.0             1.0     128.0        78.0
# 20914              0.6            1.0             1.0     132.0        80.0
# 7898               1.0            1.0             1.0     128.0        78.0
# 8829               1.5            1.0             1.0     110.0        68.0
# 46050              1.0            1.0             1.0     130.0        72.0
# 54433              0.7            1.0             1.0     129.0        87.0
# 21930              1.2            1.0             1.0     100.0        65.0
# 43267              0.9            1.0             1.0     118.0        75.0
# 16994              1.0            1.0             1.0     115.0        71.0
# 31113              1.0            1.0             1.0     124.0        76.0
#
#        fasting blood sugar  Cholesterol  triglyceride   HDL    LDL  \
# 33794                 94.0        247.0         144.0  54.0  164.0
# 20914                 98.0        224.0         122.0  60.0  138.0
# 7898                  76.0        197.0          85.0  49.0  131.0
# 8829                  84.0        263.0         122.0  50.0  189.0
# 46050                102.0        136.0          64.0  57.0   66.0
# 54433                 99.0        203.0         197.0  51.0  112.0
# 21930                 89.0        167.0          54.0  62.0   94.0
# 43267                 88.0        182.0          79.0  60.0  105.0
# 16994                152.0        166.0         160.0  50.0   84.0
# 31113                 96.0        268.0          85.0  58.0  193.0
#
#        hemoglobin  Urine protein  serum creatinine   AST   ALT    Gtp  oral  \
# 33794        14.3            1.0               0.9  25.0  35.0   61.0     0
# 20914        13.2            1.0               0.6  21.0  21.0   25.0     0
# 7898         14.9            1.0               1.0  26.0  22.0   35.0     0
# 8829         13.6            1.0               0.8  15.0  14.0   18.0     0
# 46050        13.4            1.0               0.8  29.0  29.0   19.0     0
# 54433        13.8            1.0               1.1  17.0  37.0   48.0     0
# 21930        16.4            1.0               1.1  31.0  30.0   20.0     0
# 43267        14.4            1.0               0.7  25.0  23.0   21.0     0
# 16994        13.3            1.0               0.8  41.0  80.0  101.0     0
# 31113        14.4            1.0               0.6  24.0  28.0   27.0     0
#
#        dental caries  tartar  smoking  smoking_A  smoking_P  %Error
# 33794              0       0        0          0          1    -inf
# 20914              0       0        0          0          0     NaN
# 7898               0       1        0          0          1    -inf
# 8829               0       1        0          0          0     NaN
# 46050              0       0        0          0          0     NaN
# 54433              1       1        1          1          1     0.0
# 21930              0       1        0          0          1    -inf
# 43267              0       1        1          1          0   100.0
# 16994              0       0        0          0          0     NaN
# 31113              0       1        0          0          0     NaN
